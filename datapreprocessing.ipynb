# %% [markdown]
# # Data Cleaning and Pre-Processing

# %% [markdown]
# This notebook contains the code for cleaning and pre-processing the data. The columns will be converted to numeric and categorical data types. The missing values if any will be imputed and the outliers will be removed (if any). The results will store the cleaned dataset in a new csv file.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd

# %%
df = pd.read_excel('2021_Global_Nutrition_Report_Dataset_6YAamkd (1).xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Semester 7\MacroAI\datapreprocessing.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Semester%207/MacroAI/datapreprocessing.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_excel('2021_Global_Nutrition_Report_Dataset_6YAamkd (1)')
#       <a href='vscode-notebook-cell:/c%3A/Semester%207/MacroAI/datapreprocessing.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> df.head()
#
# File c:\Users\alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File c:\Users\alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1496, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1494     ext = "xls"
#    1495 else:
# -> 1496     ext = inspect_excel_format(
#    1497         content_or_path=path_or_buffer, storage_options=storage_options
#    1498     )
#    1499     if ext is None:
#    1500         raise ValueError(
#    1501             "Excel file format cannot be determined, you must specify "
#    1502             "an engine manually."
#    1503         )
#
# File c:\Users\alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1371, in inspect_excel_format(content_or_path, storage_options)
#    1368 if isinstance(content_or_path, bytes):
#    1369     content_or_path = BytesIO(content_or_path)
# -> 1371 with get_handle(
#    1372     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1373 ) as handle:
#    1374     stream = handle.handle
#    1375     stream.seek(0)
#
# File c:\Users\alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '2021_Global_Nutrition_Report_Dataset_6YAamkd (1)'

# %% [markdown]
# Let's first observe the first and last rows of the data exracted.

# %%
df = pd.read_csv('recommended_nutrition.csv')
df.head(5)
# Out:
#     Sex       Age       Height   Weight Activity Level   BMI  Daily Calories
# 0  Male  18 years  4 ft. 0 in.  88 lbs.      Sedentary  26.9  1,166 kcal/day  \
# 1  Male  18 years  4 ft. 0 in.  90 lbs.      Sedentary  27.5  1,190 kcal/day
# 2  Male  18 years  4 ft. 0 in.  93 lbs.      Sedentary  28.4  1,227 kcal/day
# 3  Male  18 years  4 ft. 0 in.  95 lbs.      Sedentary  29.0  1,251 kcal/day
# 4  Male  18 years  4 ft. 0 in.  97 lbs.      Sedentary  29.6  1,275 kcal/day
#
#                Carbs     Fiber   Protein              Fat
# 0  131 - 189 grams\n  38 grams  34 grams  32 - 45 grams\n  \
# 1  134 - 193 grams\n  38 grams  35 grams  33 - 46 grams\n
# 2  138 - 199 grams\n  38 grams  36 grams  34 - 48 grams\n
# 3  141 - 203 grams\n  38 grams  37 grams  35 - 49 grams\n
# 4  143 - 207 grams\n  38 grams  37 grams  35 - 50 grams\n
#
#                           Water Vitamin C Vitamin A Vitamin D Vitamin E
# 0  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg  \
# 1  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
# 2  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
# 3  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
# 4  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
#
#   Vitamin B12 Vitamin K Niacin   Calcium
# 0     2.4 mcg    75 mcg  16 mg  1,300 mg
# 1     2.4 mcg    75 mcg  16 mg  1,300 mg
# 2     2.4 mcg    75 mcg  16 mg  1,300 mg
# 3     2.4 mcg    75 mcg  16 mg  1,300 mg
# 4     2.4 mcg    75 mcg  16 mg  1,300 mg

# %%
df.tail(5)
# Out:
#      Sex       Age       Height    Weight Activity Level   BMI
# 70  Male  18 years  6 ft. 0 in.  132 lbs.      Sedentary  17.9  \
# 71  Male  18 years  6 ft. 0 in.  135 lbs.      Sedentary  18.3
# 72  Male  18 years  6 ft. 0 in.  137 lbs.      Sedentary  18.6
# 73  Male  18 years  6 ft. 0 in.  139 lbs.      Sedentary  18.9
# 74  Male  18 years  6 ft. 0 in.  141 lbs.      Sedentary  19.1
#
#     Daily Calories              Carbs     Fiber   Protein              Fat
# 70  2,249 kcal/day  253 - 365 grams\n  38 grams  51 grams  62 - 87 grams\n  \
# 71  2,286 kcal/day  257 - 371 grams\n  38 grams  52 grams  64 - 89 grams\n
# 72  2,310 kcal/day  260 - 375 grams\n  38 grams  53 grams  64 - 90 grams\n
# 73  2,334 kcal/day  263 - 379 grams\n  38 grams  54 grams  65 - 91 grams\n
# 74  2,358 kcal/day  265 - 383 grams\n  38 grams  54 grams  66 - 92 grams\n
#
#                            Water Vitamin C Vitamin A Vitamin D Vitamin E
# 70  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg  \
# 71  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
# 72  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
# 73  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
# 74  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
#
#    Vitamin B12 Vitamin K Niacin   Calcium
# 70     2.4 mcg    75 mcg  16 mg  1,300 mg
# 71     2.4 mcg    75 mcg  16 mg  1,300 mg
# 72     2.4 mcg    75 mcg  16 mg  1,300 mg
# 73     2.4 mcg    75 mcg  16 mg  1,300 mg
# 74     2.4 mcg    75 mcg  16 mg  1,300 mg

# %% [markdown]
# From the first observartion, we can see that the dataset is not clean. Every column (except BMI) is an object and must be transformed to number. Also, the column names are not in a good format. We will fix these issues in this section.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             75 non-null     object
#  1   Age             75 non-null     object
#  2   Height          75 non-null     object
#  3   Weight          75 non-null     object
#  4   Activity Level  75 non-null     object
#  5   BMI             75 non-null     float64
#  6   Daily Calories  75 non-null     object
#  7   Carbs           75 non-null     object
#  8   Fiber           75 non-null     object
#  9   Protein         75 non-null     object
#  10  Fat             75 non-null     object
#  11  Water           75 non-null     object
#  12  Vitamin C       75 non-null     object
#  13  Vitamin A       75 non-null     object
#  14  Vitamin D       75 non-null     object
#  15  Vitamin E       75 non-null     object
#  16  Vitamin B12     75 non-null     object
#  17  Vitamin K       75 non-null     object
#  18  Niacin          75 non-null     object
#  19  Calcium         75 non-null     object
# dtypes: float64(1), object(19)
# memory usage: 11.8+ KB

# %% [markdown]
# Correctly, every column is an object that must be preprocess to a number.

# %%
df.isnull().sum()
# Out:
# Sex               0
# Age               0
# Height            0
# Weight            0
# Activity Level    0
# BMI               0
# Daily Calories    0
# Carbs             0
# Fiber             0
# Protein           0
# Fat               0
# Water             0
# Vitamin C         0
# Vitamin A         0
# Vitamin D         0
# Vitamin E         0
# Vitamin B12       0
# Vitamin K         0
# Niacin            0
# Calcium           0
# dtype: int64

# %% [markdown]
# Luckily, the dataset does not have any missing values. So, we do not need to deal with missing values.

# %% [markdown]
# ## Converting object columns to numeric
#
# First we will convert the most important columns from object to numeric, so that they can be imported into the model. The features that we will convert are:
# - Age
# - height
# - weight
# - daily calories

# %%
# First we need to remove the dot between the numbers in Daily Calories
df['Daily Calories'] = df['Daily Calories'].str.replace(',', '')

# Then we need to exclude all text from these columns
numeric_columns = ['Age', 'Height', 'Weight', 'Daily Calories']
for col in numeric_columns:
    df[col] = df[col].str.extract('(\d+)').astype(float)

# %%
df['Sex'] = df['Sex'].map({'Female': 0, 'Male': 1})

# %%
df.head(5)
# Out:
#    Sex   Age  Height  Weight Activity Level   BMI  Daily Calories
# 0    1  18.0     4.0    88.0      Sedentary  26.9          1166.0  \
# 1    1  18.0     4.0    90.0      Sedentary  27.5          1190.0
# 2    1  18.0     4.0    93.0      Sedentary  28.4          1227.0
# 3    1  18.0     4.0    95.0      Sedentary  29.0          1251.0
# 4    1  18.0     4.0    97.0      Sedentary  29.6          1275.0
#
#                Carbs     Fiber   Protein              Fat
# 0  131 - 189 grams\n  38 grams  34 grams  32 - 45 grams\n  \
# 1  134 - 193 grams\n  38 grams  35 grams  33 - 46 grams\n
# 2  138 - 199 grams\n  38 grams  36 grams  34 - 48 grams\n
# 3  141 - 203 grams\n  38 grams  37 grams  35 - 49 grams\n
# 4  143 - 207 grams\n  38 grams  37 grams  35 - 50 grams\n
#
#                           Water Vitamin C Vitamin A Vitamin D Vitamin E
# 0  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg  \
# 1  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
# 2  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
# 3  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
# 4  3.3 liters (about 14 cups)\n     75 mg   900 mcg    15 mcg     15 mg
#
#   Vitamin B12 Vitamin K Niacin   Calcium
# 0     2.4 mcg    75 mcg  16 mg  1,300 mg
# 1     2.4 mcg    75 mcg  16 mg  1,300 mg
# 2     2.4 mcg    75 mcg  16 mg  1,300 mg
# 3     2.4 mcg    75 mcg  16 mg  1,300 mg
# 4     2.4 mcg    75 mcg  16 mg  1,300 mg

# %% [markdown]
# We can see that now Age, height, weight and daily calories are numeric. We can now proceed to the next step where we can create sample model to predict how much calories a person needs to consume in a day based on its features.

# %% [markdown]
# ## TODO: Convert the rest of the columns

# %% [markdown]
# ## Save the dataset

# %%
df.to_csv('recommended_nutrition_cleaned.csv', index=False)
